# %%
def listar(cinema):
    lista = []
    for sala in cinema:
        lista.append(sala[2])

    return lista

def disponivel(cinema,filme,lugar):

    cond = False
    for sala in cinema:
        if filme == sala[2]:
            if lugar not in sala[1]:
                cond = True

    return cond 

def vende_bilhete(cinema, filme, lugar):
    if disponivel(cinema,filme,lugar):
        for sala in cinema:
            if filme == sala[2]:
                sala[1].append(sala[1])

    return cinema 

def listar_disponibilidades(cinema):
    l = []
    for sala in cinema:
        info = (sala[2], sala[0 - len[sala[1]]])
        l.append(info)

    return l

def inserir_sala(cinema,sala):
    if sala not in cinema:
        cinema.append(sala)

def menu():
    num = int(input("Escreva a opção: "))

    if num == 1:
        l = listar(cinema)
        for i in l:
            print(filme)

    if num == 2:
        cinema = str(input("Escolha o cinema: "))
        lugar = int(input("Escolha o lugar: "))
        filme = str(input("Escolha o filme: "))
        cond = disponivel(cinema, input("Qual é o filme?"))
        cond = disponivel(cinema, filme, lugar)
        if cond:
            print("O seu lugar está disponível!")
        else:
            print("O seu lugar está indisponível!")

    if num == 3:
        cinema = str(input("Escolha o cinema"))
        lugar = int(input("Escolha o lugar"))
        filme = str(input("Escolha o filme"))
        vende_bilhete(cinema, filme, lugar)

    if num == 4:
        print(listar_disponibilidades(str(input("Escolha o cinema"))))

    if num == 5:
        cinema = str(input("Escolha o cinema"))
        num_lugares = int(input("Insira o número de lugares:"))
        n = int(input("Quantos lugares são?"))
        lista = []
        for i in range (n):
            num = int(input("Qual é o número do lugar?"))
            lista.append(num)
        
        filme = str(input("Insira um filme:"))
        sala = (num_lugares, lista, filme)
        inserir_sala(cinema, sala)
